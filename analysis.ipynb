# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('fatal-police-shootings-data.csv')
df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# ...

# %%
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
df.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  year
# 0  Not fleeing        False  2015
# ...

# %%
df.year.unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020])

# %%
df.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
df['manner_of_death'] = 'shot' # Shot and teasered can be treated as just shot

# %%
df.manner_of_death.unique()
# Out:
# array(['shot'], dtype=object)

# %%
df_2015 = df[df['year'] == 2015]
df_2015.loc[:, ('total')] = df_2015['state'].map(df_2015['state'].value_counts())
df_2015.head()
# Out:
#    id                name        date manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02            shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02            shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03            shot     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04            shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04            shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  year  total
# 0  Not fleeing        False  2015     16
# ...

# %%
df_2016 = df[df['year'] == 2016]
df_2016.loc[:, ('total')] = df_2016['state'].map(df_2016['state'].value_counts())
df_2016.head()
# Out:
#        id                   name        date manner_of_death  armed   age  \
# 994  1139          Joshua Sisson  2016-01-01            shot  knife  30.0
# 995  1195            Lance Light  2016-01-02            shot    gun  54.0
# 996  1198  Lonnie Haskell Powers  2016-01-02            shot    gun  37.0
# 997  1138           Sean O'Brien  2016-01-02            shot  knife  37.0
# 998  1140       Germonta Wallace  2016-01-03            shot    gun  30.0
#
#     gender race         city state  signs_of_mental_illness threat_level  \
# 994      M    W    San Diego    CA                    False        other
# 995      M    W     Maryneal    TX                    False       attack
# 996      M    W  Sioux Falls    SD                    False       attack
# 997      M    W   Livingston    MT                    False        other
# 998      M    B    Charlotte    NC                    False       attack
#
#             flee  body_camera  year  total
# ...

# %%
df_2017 = df[df['year'] == 2017]
df_2017.loc[:, ('total')] = df_2017['state'].map(df_2017['state'].value_counts())
df_2017.head()
# Out:
#         id                name        date manner_of_death  armed   age  \
# 1956  2177     John McLaughlin  2017-01-01            shot    gun  42.0
# 1957  2178      Trevon Johnson  2017-01-01            shot  knife  17.0
# 1958  2184   Chad Erik Roberts  2017-01-01            shot    gun  35.0
# 1959  2185  Juan Carlos Cuadra  2017-01-01            shot    gun  23.0
# 1960  2187       Mark Guirguis  2017-01-01            shot    NaN  21.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 1956      M    W  Springfield    OH                    False        other
# 1957      M    B   Villa Park    IL                     True        other
# 1958      M    W    Woodstock    GA                    False       attack
# 1959      M    H      Houston    TX                    False       attack
# 1960      M    B        Allen    TX                    False       attack
#
#              flee  body_camera  year  total
# ...

# %%
df_2018 = df[df['year'] == 2018]
df_2018.loc[:, ('total')] = df_2018['state'].map(df_2018['state'].value_counts())
df_2018.head()
# Out:
#         id                   name        date manner_of_death armed   age  \
# 2942  3275  Mark Steven Parkinson  2018-01-01            shot   gun  65.0
# 2943  3288      Archie Lawhon III  2018-01-01            shot   gun  42.0
# 2944  3289             Gary Johns  2018-01-01            shot   gun  65.0
# 2945  3291    Shana Diane Musquiz  2018-01-02            shot   gun  30.0
# 2946  3292          Ronald Elliot  2018-01-02            shot   gun  49.0
#
#      gender race       city state  signs_of_mental_illness threat_level  \
# 2942      M    W  Rossville    GA                     True       attack
# 2943      M    W    Romance    AR                    False       attack
# 2944      M    W  Edgewater    FL                     True       attack
# 2945      F    W  Camp Wood    TX                    False       attack
# 2946      M    W      Ozark    AR                     True       attack
#
#              flee  body_camera  year  total
# ...

# %%
df_2019 = df[df['year'] == 2019]
df_2019.loc[:, ('total')] = df_2019['state'].map(df_2019['state'].value_counts())
df_2019.head()
# Out:
#         id                    name        date manner_of_death    armed   age  \
# 3932  4334     Dylan Michael Smith  2019-01-01            shot      gun  26.0
# 3933  4504  Brandon Lovell Webster  2019-01-01            shot  vehicle  28.0
# 3934  4342       Matthew Burroughs  2019-01-02            shot  vehicle  35.0
# 3935  4343         Abdoulaye Thiam  2019-01-02            shot    knife  20.0
# 3936  4345    Arron Thomas Lambert  2019-01-02            shot    Taser  33.0
#
#      gender race             city state  signs_of_mental_illness threat_level  \
# 3932      M    W  Davidson County    NC                    False       attack
# 3933      M    B        Shallotte    NC                    False        other
# 3934      M    B            Niles    OH                    False       attack
# 3935      M    B       Whitehaven    TN                    False        other
# 3936      M    W      San Antonio    TX                    False       attack
#
# ...

# %%
df_2020 = df[df['year'] == 2020]
df_2020.loc[:, ('total')] = df_2020['state'].map(df_2020['state'].value_counts())
df_2020.head()
# Out:
#         id                            name        date manner_of_death  \
# 4931  5344               Derrick A. Elseth  2020-01-01            shot
# 4932  5347     Teddy James Maverick Varner  2020-01-01            shot
# 4933  5403  Gerardo Antonio Conchas-Bustas  2020-01-01            shot
# 4934  5342              Gabriel Strickland  2020-01-01            shot
# 4935  5339            Jeffery Dale Millsap  2020-01-02            shot
#
#            armed   age gender race             city state  \
# 4931         gun  24.0      M    W  Richmond County    VA
# 4932         gun  29.0      M  NaN    Central Point    OR
# 4933       knife  20.0      M    O           Denver    CO
# 4934  toy weapon  25.0      M    W     Grass Valley    CA
# 4935         gun  26.0      M    W             Holt    MO
#
#       signs_of_mental_illness threat_level         flee  body_camera  year  \
# 4931                    False        other  Not fleeing        False  2020
# ...

# %%
fig_2015 = go.Figure(data=go.Choropleth(
    locations=df_2015['state'].to_list(),
    z=df_2015['total'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2015['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings"
))

fig_2015.update_layout(
    title_text='2015 shootings data',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2015.show()
# Out:
# <div>
#
#
#             <div id="28c3d003-63c3-4966-981b-7c9e96b2b82f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("28c3d003-63c3-4966-981b-7c9e96b2b82f")) {
#                     Plotly.newPlot(
#                         '28c3d003-63c3-4966-981b-7c9e96b2b82f',
# ...

# %%
fig_2016 = go.Figure(data=go.Choropleth(
    locations=df_2016['state'].to_list(),
    z=df_2016['total'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2016['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings"
))

fig_2016.update_layout(
    title_text='2016 shootings data',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2016.show()
# Out:
# <div>
#
#
#             <div id="24b48ac1-9408-4eb8-8c95-d3928fe471f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("24b48ac1-9408-4eb8-8c95-d3928fe471f5")) {
#                     Plotly.newPlot(
#                         '24b48ac1-9408-4eb8-8c95-d3928fe471f5',
# ...

# %%
fig_2017 = go.Figure(data=go.Choropleth(
    locations=df_2017['state'].to_list(),
    z=df_2017['total'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2017['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings"
))

fig_2017.update_layout(
    title_text='2017 shootings data',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2017.show()
# Out:
# <div>
#
#
#             <div id="8e32dbf1-36de-4d19-ab5e-6d9ede2ebe63" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e32dbf1-36de-4d19-ab5e-6d9ede2ebe63")) {
#                     Plotly.newPlot(
#                         '8e32dbf1-36de-4d19-ab5e-6d9ede2ebe63',
# ...

# %%
fig_2018 = go.Figure(data=go.Choropleth(
    locations=df_2018['state'].to_list(),
    z=df_2018['total'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2018['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings"
))

fig_2018.update_layout(
    title_text='2018 shootings data',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2018.show()
# Out:
# <div>
#
#
#             <div id="e863c7f8-49e3-4d49-9d32-10063e2cfd05" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e863c7f8-49e3-4d49-9d32-10063e2cfd05")) {
#                     Plotly.newPlot(
#                         'e863c7f8-49e3-4d49-9d32-10063e2cfd05',
# ...

# %%
fig_2019 = go.Figure(data=go.Choropleth(
    locations=df_2019['state'].to_list(),
    z=df_2019['total'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2019['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings"
))

fig_2019.update_layout(
    title_text='2019 shootings data',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2019.show()
# Out:
# <div>
#
#
#             <div id="e52d28eb-7651-4438-8775-95505f95be66" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e52d28eb-7651-4438-8775-95505f95be66")) {
#                     Plotly.newPlot(
#                         'e52d28eb-7651-4438-8775-95505f95be66',
# ...

# %%
fig_2020 = go.Figure(data=go.Choropleth(
    locations=df_2020['state'].to_list(),
    z=df_2020['total'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2020['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings"
))

fig_2020.update_layout(
    title_text='2020 shootings data',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2020.show()
# Out:
# <div>
#
#
#             <div id="4a3ae990-1188-448e-8ea8-3ad2a6cd7dab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a3ae990-1188-448e-8ea8-3ad2a6cd7dab")) {
#                     Plotly.newPlot(
#                         '4a3ae990-1188-448e-8ea8-3ad2a6cd7dab',
# ...

# %%
df.loc[:, ('total')] = df['state'].map(df['state'].value_counts())
df.head()
# Out:
#    id                name        date manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02            shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02            shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03            shot     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04            shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04            shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  year  total
# 0  Not fleeing        False  2015    153
# ...

# %%
fig = go.Figure(data=go.Choropleth(
    locations=df['state'].to_list(),
    z=df['total'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings"
))

fig.update_layout(
    title_text='2015 - 2020 shootings data',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig.show()
# Out:
# <div>
#
#
#             <div id="2510bedb-3807-49c7-956b-4afdce6fccdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2510bedb-3807-49c7-956b-4afdce6fccdb")) {
#                     Plotly.newPlot(
#                         '2510bedb-3807-49c7-956b-4afdce6fccdb',
# ...

# %% [markdown]
# Above maps are misleading because we have to take into account the population of a state also. Creating a heatmap of fatal shootings as a ratio of the population by state will be more accurate

# %%
population = pd.read_csv('state_populations_from_census_gov.csv')
population.head()
# Out:
#         State      2010      2011      2012      2013      2014      2015  \
# 0     Alabama   4785437   4799069   4815588   4830081   4841799   4852347
# 1      Alaska    713910    722128    730443    737068    736283    737498
# 2     Arizona   6407172   6472643   6554978   6632764   6730413   6829676
# 3    Arkansas   2921964   2940667   2952164   2959400   2967392   2978048
# 4  California  37319502  37638369  37948800  38260787  38596972  38918045
#
#        2016      2017      2018      2019
# 0   4863525   4874486   4887681   4903185
# 1    741456    739700    735139    731545
# 2   6941072   7044008   7158024   7278717
# 3   2989918   3001345   3009733   3017804
# 4  39167117  39358497  39461588  39512223

# %%
population_2020 = pd.read_csv('csvData.csv')
population_2020.rename(columns={"Pop": "2020"}, inplace = True)
population_2020.head()
# Out:
#    rank         State      2020  Growth   Pop2018   Pop2010  growthSince2010  \
# 0     1    California  39937500  0.0096  39557000  37320900           0.0701
# 1     2         Texas  29472300  0.0268  28701800  25242700           0.1676
# 2     3       Florida  21993000  0.0326  21299300  18845800           0.1670
# 3     4      New York  19440500 -0.0052  19542200  19400100           0.0021
# 4     5  Pennsylvania  12820900  0.0011  12807100  12711200           0.0086
#
#    Percent   density
# 0   0.1194  256.3728
# 1   0.0881  112.8204
# 2   0.0658  410.1259
# 3   0.0581  412.5218
# 4   0.0383  286.5454

# %%
population = pd.merge(population, population_2020[['State','2020']].copy(), on='State')
population.rename(columns={"2015": "2015_pop", "2016":"2016_pop", "2017":"2017_pop", "2018":"2018_pop", "2019":"2019_pop", "2020":"2020_pop"}, inplace = True)
population.head()
# Out:
#         State      2010      2011      2012      2013      2014  2015_pop  \
# 0     Alabama   4785437   4799069   4815588   4830081   4841799   4852347
# 1      Alaska    713910    722128    730443    737068    736283    737498
# 2     Arizona   6407172   6472643   6554978   6632764   6730413   6829676
# 3    Arkansas   2921964   2940667   2952164   2959400   2967392   2978048
# 4  California  37319502  37638369  37948800  38260787  38596972  38918045
#
#    2016_pop  2017_pop  2018_pop  2019_pop  2020_pop
# 0   4863525   4874486   4887681   4903185   4908620
# 1    741456    739700    735139    731545    734002
# 2   6941072   7044008   7158024   7278717   7378490
# 3   2989918   3001345   3009733   3017804   3039000
# 4  39167117  39358497  39461588  39512223  39937500

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
population['State'] = population.State.replace(us_state_abbrev)
population.rename(columns={"State": "state"},inplace=True)

# %%
population.head()
# Out:
#   state      2010      2011      2012      2013      2014  2015_pop  2016_pop  \
# 0    AL   4785437   4799069   4815588   4830081   4841799   4852347   4863525
# 1    AK    713910    722128    730443    737068    736283    737498    741456
# 2    AZ   6407172   6472643   6554978   6632764   6730413   6829676   6941072
# 3    AR   2921964   2940667   2952164   2959400   2967392   2978048   2989918
# 4    CA  37319502  37638369  37948800  38260787  38596972  38918045  39167117
#
#    2017_pop  2018_pop  2019_pop  2020_pop
# 0   4874486   4887681   4903185   4908620
# 1    739700    735139    731545    734002
# 2   7044008   7158024   7278717   7378490
# 3   3001345   3009733   3017804   3039000
# 4  39358497  39461588  39512223  39937500

# %%
population.isnull().sum()
# Out:
# state       0
# 2010        0
# 2011        0
# 2012        0
# 2013        0
# 2014        0
# 2015_pop    0
# 2016_pop    0
# 2017_pop    0
# 2018_pop    0
# 2019_pop    0
# 2020_pop    0
# dtype: int64

# %%
df = pd.merge(df, population[['state','2015_pop','2016_pop','2017_pop','2018_pop','2019_pop','2020_pop']].copy(), on='state')
df.head()
# Out:
#     id                     name        date manner_of_death       armed   age  \
# 0    3               Tim Elliot  2015-01-02            shot         gun  53.0
# 1  138  Antonio Zambrano-Montes  2015-02-10            shot     unarmed  35.0
# 2  295       Jamison  Childress  2015-03-19            shot     unarmed  20.0
# 3  393       Daniel Covarrubias  2015-04-21            shot     unarmed  37.0
# 4  431               Roark Cook  2015-05-04            shot  toy weapon  36.0
#
#   gender race       city state  ...         flee body_camera  year  total  \
# 0      M    A    Shelton    WA  ...  Not fleeing       False  2015    153
# 1      M    H      Pasco    WA  ...         Foot       False  2015    153
# 2      M    W      Sumas    WA  ...  Not fleeing       False  2015    153
# 3      M    N   Lakewood    WA  ...         Foot       False  2015    153
# 4      M    W  Kennewick    WA  ...  Not fleeing       False  2015    153
#
# ...

# %%
df_2015 = pd.merge(df_2015, population[['state','2015_pop']].copy(), on='state')
df_2015['ratio_by_population_per_mil'] = (df_2015['total'] / df_2015['2015_pop']) * 1000000
df_2015.head()
# Out:
#     id                     name        date manner_of_death       armed   age  \
# 0    3               Tim Elliot  2015-01-02            shot         gun  53.0
# 1  138  Antonio Zambrano-Montes  2015-02-10            shot     unarmed  35.0
# 2  295       Jamison  Childress  2015-03-19            shot     unarmed  20.0
# 3  393       Daniel Covarrubias  2015-04-21            shot     unarmed  37.0
# 4  431               Roark Cook  2015-05-04            shot  toy weapon  36.0
#
#   gender race       city state  signs_of_mental_illness threat_level  \
# 0      M    A    Shelton    WA                     True       attack
# 1      M    H      Pasco    WA                     True        other
# 2      M    W      Sumas    WA                     True       attack
# 3      M    N   Lakewood    WA                     True        other
# 4      M    W  Kennewick    WA                     True       attack
#
#           flee  body_camera  year  total  2015_pop  \
# ...

# %%
df_2016 = pd.merge(df_2016, population[['state','2016_pop']].copy(), on='state')
df_2016['ratio_by_population_per_mil'] = (df_2016['total'] / df_2016['2016_pop']) * 1000000
df_2016.head()
# Out:
#      id               name        date manner_of_death       armed   age  \
# 0  1139      Joshua Sisson  2016-01-01            shot       knife  30.0
# 1  1148    Stephen Bukwich  2016-01-05            shot         gun  52.0
# 2  1149    Albert Thompson  2016-01-05            shot  hand torch  28.0
# 3  1162  Alan Paul Bartley  2016-01-11            shot         NaN  56.0
# 4  1169   Miguel Hernandez  2016-01-14            shot       knife  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    W      San Diego    CA                    False        other
# 1      M    W        Redding    CA                     True        other
# 2      M    H          Ceres    CA                    False        other
# 3      M    W   San Fernando    CA                    False       attack
# 4      M    H  Santa Clarita    CA                    False        other
#
#           flee  body_camera  year  total  2016_pop  \
# ...

# %%
df_2017 = pd.merge(df_2017, population[['state','2017_pop']].copy(), on='state')
df_2017['ratio_by_population_per_mil'] = (df_2017['total'] / df_2017['2017_pop']) * 1000000
df_2017.head()
# Out:
#      id             name        date manner_of_death       armed   age gender  \
# 0  2177  John McLaughlin  2017-01-01            shot         gun  42.0      M
# 1  2268  William Brigham  2017-01-26            shot  metal pipe  34.0      M
# 2  2286    Shelly Porter  2017-02-05            shot         gun  41.0      M
# 3  2312  Richard Latimer  2017-02-07            shot         gun  34.0      M
# 4  2313    Vincent Palma  2017-02-09            shot     unarmed  26.0      M
#
#   race              city state  signs_of_mental_illness threat_level  \
# 0    W       Springfield    OH                    False        other
# 1    W  Madison Township    OH                    False        other
# 2    B         Englewood    OH                     True       attack
# 3    W  Howland Township    OH                    False       attack
# 4    W   Geneva Township    OH                    False        other
#
#           flee  body_camera  year  total  2017_pop  \
# ...

# %%
df_2018 = pd.merge(df_2018, population[['state','2018_pop']].copy(), on='state')
df_2018['ratio_by_population_per_mil'] = (df_2018['total'] / df_2018['2018_pop']) * 1000000
df_2018.head()
# Out:
#      id                   name        date manner_of_death       armed   age  \
# 0  3275  Mark Steven Parkinson  2018-01-01            shot         gun  65.0
# 1  3327            Jason Lappe  2018-01-20            shot         gun  44.0
# 2  3342      Ricky Jerome Boyd  2018-01-23            shot      BB gun  24.0
# 3  3353        Steven Hutchins  2018-01-25            shot  toy weapon  27.0
# 4  3356     Paul David Johnson  2018-01-28            shot         gun  38.0
#
#   gender race            city state  signs_of_mental_illness threat_level  \
# 0      M    W       Rossville    GA                     True       attack
# 1      M    W        Dunwoody    GA                    False        other
# 2      M    B  Chatham County    GA                    False       attack
# 3      M    W          Buford    GA                     True       attack
# 4      M    W        Chamblee    GA                    False       attack
#
#           flee  body_camera  year  total  2018_pop  \
# ...

# %%
df_2019 = pd.merge(df_2019, population[['state','2019_pop']].copy(), on='state')
df_2019['ratio_by_population_per_mil'] = (df_2019['total'] / df_2019['2019_pop']) * 1000000
df_2019.head()
# Out:
#      id                    name        date manner_of_death    armed   age  \
# 0  4334     Dylan Michael Smith  2019-01-01            shot      gun  26.0
# 1  4504  Brandon Lovell Webster  2019-01-01            shot  vehicle  28.0
# 2  4401            Danny Kelley  2019-01-16            shot    knife  32.0
# 3  4447        Jonathan Ramirez  2019-02-09            shot      gun  28.0
# 4  4479       Greg Alyn Carlson  2019-02-13            shot      gun  47.0
#
#   gender race             city state  signs_of_mental_illness threat_level  \
# 0      M    W  Davidson County    NC                    False       attack
# 1      M    B        Shallotte    NC                    False        other
# 2      M    W        Charlotte    NC                    False        other
# 3      M    H           Bailey    NC                    False        other
# 4      M    W             Apex    NC                    False       attack
#
#           flee  body_camera  year  total  2019_pop  \
# ...

# %%
df_2020 = pd.merge(df_2020, population[['state','2020_pop']].copy(), on='state')
df_2020['ratio_by_population_per_mil'] = (df_2020['total'] / df_2020['2020_pop']) * 1000000
df_2020.head()
# Out:
#      id                  name        date manner_of_death  armed   age gender  \
# 0  5344     Derrick A. Elseth  2020-01-01            shot    gun  24.0      M
# 1  5525  Hans Alejandro Huitz  2020-02-12            shot    gun  51.0      M
# 2  5613     Ajay Kamil Ayseli  2020-03-05            shot  knife  31.0      M
# 3  5666         Dakota Yancey  2020-03-15            shot    gun  19.0      M
# 4  5639   Dakota Wayne Yancey  2020-03-16            shot    gun  18.0      M
#
#   race             city state  signs_of_mental_illness threat_level  \
# 0    W  Richmond County    VA                    False        other
# 1    N   Virginia Beach    VA                    False       attack
# 2    O          Henrico    VA                    False       attack
# 3    W       Chase City    VA                    False        other
# 4    W      Mecklenburg    VA                    False       attack
#
#           flee  body_camera  year  total  2020_pop  \
# ...

# %%
fig_2015_pop_ratio_per_mil = go.Figure(data=go.Choropleth(
    locations=df_2015['state'].to_list(),
    z=df_2015['ratio_by_population_per_mil'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2015['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings per million"
))

fig_2015_pop_ratio_per_mil.update_layout(
    title_text='2015 shootings data ratio by population per million',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2015_pop_ratio_per_mil.show()
# Out:
# <div>
#
#
#             <div id="c5d5d0b1-fc4f-4f10-a711-604bc4182455" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c5d5d0b1-fc4f-4f10-a711-604bc4182455")) {
#                     Plotly.newPlot(
#                         'c5d5d0b1-fc4f-4f10-a711-604bc4182455',
# ...

# %%
fig_2016_pop_ratio_per_mil = go.Figure(data=go.Choropleth(
    locations=df_2016['state'].to_list(),
    z=df_2016['ratio_by_population_per_mil'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2016['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings per million"
))

fig_2016_pop_ratio_per_mil.update_layout(
    title_text='2016 shootings data ratio by population per million',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2016_pop_ratio_per_mil.show()
# Out:
# <div>
#
#
#             <div id="fb1b2f98-1905-4a0d-ae3d-471789622549" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fb1b2f98-1905-4a0d-ae3d-471789622549")) {
#                     Plotly.newPlot(
#                         'fb1b2f98-1905-4a0d-ae3d-471789622549',
# ...

# %%
fig_2017_pop_ratio_per_mil = go.Figure(data=go.Choropleth(
    locations=df_2017['state'].to_list(),
    z=df_2017['ratio_by_population_per_mil'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2017['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings per million"
))

fig_2017_pop_ratio_per_mil.update_layout(
    title_text='2017 shootings data per million',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2017_pop_ratio_per_mil.show()
# Out:
# <div>
#
#
#             <div id="b0fbabfc-e309-432c-bd76-df4669b9fdb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b0fbabfc-e309-432c-bd76-df4669b9fdb7")) {
#                     Plotly.newPlot(
#                         'b0fbabfc-e309-432c-bd76-df4669b9fdb7',
# ...

# %%
fig_2018_pop_ratio_per_mil = go.Figure(data=go.Choropleth(
    locations=df_2018['state'].to_list(),
    z=df_2018['ratio_by_population_per_mil'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2018['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings per million"
))

fig_2018_pop_ratio_per_mil.update_layout(
    title_text='2018 shootings data per million',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2018_pop_ratio_per_mil.show()
# Out:
# <div>
#
#
#             <div id="f54546a1-2b8a-446b-b8d7-5636bbe80473" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f54546a1-2b8a-446b-b8d7-5636bbe80473")) {
#                     Plotly.newPlot(
#                         'f54546a1-2b8a-446b-b8d7-5636bbe80473',
# ...

# %%
fig_2019_pop_ratio_per_mil = go.Figure(data=go.Choropleth(
    locations=df_2019['state'].to_list(),
    z=df_2019['ratio_by_population_per_mil'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2019['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings per million"
))

fig_2019_pop_ratio_per_mil.update_layout(
    title_text='2019 shootings data per million',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2019_pop_ratio_per_mil.show()
# Out:
# <div>
#
#
#             <div id="f5977d30-bd12-49a7-b8ee-30e390a009b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f5977d30-bd12-49a7-b8ee-30e390a009b7")) {
#                     Plotly.newPlot(
#                         'f5977d30-bd12-49a7-b8ee-30e390a009b7',
# ...

# %%
fig_2020_pop_ratio_per_mil = go.Figure(data=go.Choropleth(
    locations=df_2020['state'].to_list(),
    z=df_2020['ratio_by_population_per_mil'].to_list(),
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=df_2020['manner_of_death'].to_list(), # hover text
    marker_line_color='white', # line markers between states
    colorbar_title="Fatal shootings per million"
))

fig_2020_pop_ratio_per_mil.update_layout(
    title_text='2020 shootings data per million',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
        dragmode=False,
)

fig_2020_pop_ratio_per_mil.show()
# Out:
# <div>
#
#
#             <div id="7d6ce8c4-002c-467e-8726-8e0174ef465d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7d6ce8c4-002c-467e-8726-8e0174ef465d")) {
#                     Plotly.newPlot(
#                         '7d6ce8c4-002c-467e-8726-8e0174ef465d',
# ...

# %% [markdown]
# Note: Year 2020 is not complete yet

# %%
df.race.unique()
# Out:
# array(['A', 'H', 'W', 'N', 'O', 'B', nan], dtype=object)

# %%
df.head()
# Out:
#     id                     name        date manner_of_death       armed   age  \
# 0    3               Tim Elliot  2015-01-02            shot         gun  53.0
# 1  138  Antonio Zambrano-Montes  2015-02-10            shot     unarmed  35.0
# 2  295       Jamison  Childress  2015-03-19            shot     unarmed  20.0
# 3  393       Daniel Covarrubias  2015-04-21            shot     unarmed  37.0
# 4  431               Roark Cook  2015-05-04            shot  toy weapon  36.0
#
#   gender race       city state  ...         flee body_camera  year  total  \
# 0      M    A    Shelton    WA  ...  Not fleeing       False  2015    153
# 1      M    H      Pasco    WA  ...         Foot       False  2015    153
# 2      M    W      Sumas    WA  ...  Not fleeing       False  2015    153
# 3      M    N   Lakewood    WA  ...         Foot       False  2015    153
# 4      M    W  Kennewick    WA  ...  Not fleeing       False  2015    153
#
# ...

# %% [markdown]
# Only have population distribution data by race from 2015 to 2018 so not going to plot 2019 and 2020 graphs

# %%
total_natives = []
seriesObj = df_2015.apply(lambda x: True if x['race'] == 'A' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_natives.append(numOfRows)
#######
seriesObj = df_2016.apply(lambda x: True if x['race'] == 'A' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_natives.append(numOfRows)
#######
seriesObj = df_2017.apply(lambda x: True if x['race'] == 'A' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_natives.append(numOfRows)
#######
seriesObj = df_2018.apply(lambda x: True if x['race'] == 'A' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_natives.append(numOfRows)
#######
# seriesObj = df_2019.apply(lambda x: True if x['race'] == 'A' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_natives.append(numOfRows)
# #######
# seriesObj = df_2020.apply(lambda x: True if x['race'] == 'A' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_natives.append(numOfRows)

total_natives
# Out:
# [14, 15, 16, 21]

# %%
total_blacks = []
seriesObj = df_2015.apply(lambda x: True if x['race'] == 'B' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_blacks.append(numOfRows)
#######
seriesObj = df_2016.apply(lambda x: True if x['race'] == 'B' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_blacks.append(numOfRows)
#######
seriesObj = df_2017.apply(lambda x: True if x['race'] == 'B' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_blacks.append(numOfRows)
#######
seriesObj = df_2018.apply(lambda x: True if x['race'] == 'B' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_blacks.append(numOfRows)
#######
# seriesObj = df_2019.apply(lambda x: True if x['race'] == 'B' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_blacks.append(numOfRows)
# #######
# seriesObj = df_2020.apply(lambda x: True if x['race'] == 'B' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_blacks.append(numOfRows)

total_blacks
# Out:
# [258, 234, 224, 228]

# %%
total_hispanics = []
seriesObj = df_2015.apply(lambda x: True if x['race'] == 'H' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_hispanics.append(numOfRows)
#######
seriesObj = df_2016.apply(lambda x: True if x['race'] == 'H' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_hispanics.append(numOfRows)
#######
seriesObj = df_2017.apply(lambda x: True if x['race'] == 'H' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_hispanics.append(numOfRows)
#######
seriesObj = df_2018.apply(lambda x: True if x['race'] == 'H' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_hispanics.append(numOfRows)
#######
# seriesObj = df_2019.apply(lambda x: True if x['race'] == 'H' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_hispanics.append(numOfRows)
# #######
# seriesObj = df_2020.apply(lambda x: True if x['race'] == 'H' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_hispanics.append(numOfRows)

total_hispanics
# Out:
# [172, 160, 180, 165]

# %%
total_whites = []
seriesObj = df_2015.apply(lambda x: True if x['race'] == 'W' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_whites.append(numOfRows)
#######
seriesObj = df_2016.apply(lambda x: True if x['race'] == 'W' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_whites.append(numOfRows)
#######
seriesObj = df_2017.apply(lambda x: True if x['race'] == 'W' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_whites.append(numOfRows)
#######
seriesObj = df_2018.apply(lambda x: True if x['race'] == 'W' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_whites.append(numOfRows)
#######
# seriesObj = df_2019.apply(lambda x: True if x['race'] == 'W' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_whites.append(numOfRows)
# #######
# seriesObj = df_2020.apply(lambda x: True if x['race'] == 'W' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_whites.append(numOfRows)

total_whites
# Out:
# [498, 469, 461, 456]

# %%
total_non_hispanics = []
seriesObj = df_2015.apply(lambda x: True if x['race'] == 'N' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_non_hispanics.append(numOfRows)
#######
seriesObj = df_2016.apply(lambda x: True if x['race'] == 'N' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_non_hispanics.append(numOfRows)
#######
seriesObj = df_2017.apply(lambda x: True if x['race'] == 'N' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_non_hispanics.append(numOfRows)
#######
seriesObj = df_2018.apply(lambda x: True if x['race'] == 'N' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_non_hispanics.append(numOfRows)
#######
# seriesObj = df_2019.apply(lambda x: True if x['race'] == 'N' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_non_hispanics.append(numOfRows)
# #######
# seriesObj = df_2020.apply(lambda x: True if x['race'] == 'N' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_non_hispanics.append(numOfRows)

total_non_hispanics
# Out:
# [9, 16, 22, 15]

# %%
total_unknown = []
seriesObj = df_2015.apply(lambda x: True if x['race'] == 'O' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_unknown.append(numOfRows)
#######
seriesObj = df_2016.apply(lambda x: True if x['race'] == 'O' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_unknown.append(numOfRows)
#######
seriesObj = df_2017.apply(lambda x: True if x['race'] == 'O' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_unknown.append(numOfRows)
#######
seriesObj = df_2018.apply(lambda x: True if x['race'] == 'O' else False , axis=1)
numOfRows = len(seriesObj[seriesObj == True].index)
total_unknown.append(numOfRows)
#######
# seriesObj = df_2019.apply(lambda x: True if x['race'] == 'O' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_unknown.append(numOfRows)
# #######
# seriesObj = df_2020.apply(lambda x: True if x['race'] == 'O' else False , axis=1)
# numOfRows = len(seriesObj[seriesObj == True].index)
# total_unknown.append(numOfRows)

total_unknown
# Out:
# [15, 11, 6, 4]

# %%
index = [2015,2016,2017,2018]
pd.DataFrame({'American_Native': total_natives, 
              'Black': total_blacks, 
              'Hispanic': total_hispanics, 
              'White': total_whites,
              'Not_hispanics': total_non_hispanics,
              'Unknown': total_unknown,
              }, index=index).plot(kind='bar', width=0.8).legend(bbox_to_anchor=(1.1, 1))

# %% [markdown]
# From the above graph it looks like people who identify as white are disproportionately affected but this graph is a little misleading because we need to divide these by the population distribution of each race. We will concentrate on Blacks, Whites and Hispanics because other races seem to have minscule affect on the trends

# %%
population_dist_2015 = pd.read_csv('2015_pop_dist_by_race.csv')
population_dist_2015.head()
# Out:
#         Location  White  Black  Hispanic  American Indian/Alaska Native  \
# 0  United States   0.62   0.12      0.18                           0.01
#
#    Asian Native Hawaiian/Other Pacific Islander  Two Or More Races  Total  \
# 0   0.05                                   <.01               0.03    1.0
#
#    Footnotes
# 0          1

# %%
population_dist_2016 = pd.read_csv('2016_pop_dist_by_race.csv')
population_dist_2016.head()
# Out:
#         Location  White  Black  Hispanic  American Indian/Alaska Native  \
# 0  United States   0.61   0.12      0.18                           0.01
#
#    Asian Native Hawaiian/Other Pacific Islander  Two Or More Races  Total  \
# 0   0.05                                   <.01               0.03    1.0
#
#    Footnotes
# 0          1

# %%
population_dist_2017 = pd.read_csv('2017_pop_dist_by_race.csv')
population_dist_2017.head()
# Out:
#         Location  White  Black  Hispanic  American Indian/Alaska Native  \
# 0  United States   0.61   0.12      0.18                           0.01
#
#    Asian Native Hawaiian/Other Pacific Islander  Two Or More Races  Total  \
# 0   0.06                                   <.01               0.03    1.0
#
#    Footnotes
# 0          1

# %%
population_dist_2018 = pd.read_csv('2018_pop_dist_by_race.csv')
population_dist_2018.head()
# Out:
#         Location  White  Black  Hispanic  American Indian/Alaska Native  \
# 0  United States    0.6   0.12      0.18                           0.01
#
#    Asian Native Hawaiian/Other Pacific Islander  Two Or More Races  Total  \
# 0   0.06                                   <.01               0.03    1.0
#
#    Footnotes
# 0          1

# %%
population_dist_whites = [population_dist_2015['White'].values[0], 
                          population_dist_2016['White'].values[0],
                          population_dist_2017['White'].values[0],
                          population_dist_2018['White'].values[0],
                         ]
population_dist_whites
# Out:
# [0.62, 0.61, 0.61, 0.6]

# %%
population_dist_blacks = [population_dist_2015['Black'].values[0], 
                          population_dist_2016['Black'].values[0],
                          population_dist_2017['Black'].values[0],
                          population_dist_2018['Black'].values[0],
                         ]
population_dist_blacks
# Out:
# [0.12, 0.12, 0.12, 0.12]

# %%
population_dist_hispanics = [population_dist_2015['Hispanic'].values[0], 
                             population_dist_2016['Hispanic'].values[0],
                             population_dist_2017['Hispanic'].values[0],
                             population_dist_2018['Hispanic'].values[0],
                         ]
population_dist_hispanics
# Out:
# [0.18, 0.18, 0.18, 0.18]

# %%
index = [2015,2016,2017,2018]
pd.DataFrame({ 'White': np.array(total_whites, dtype=np.float) / np.array(population_dist_whites, dtype=np.float).tolist(),
               'Blacks': np.array(total_blacks, dtype=np.float) / np.array(population_dist_blacks, dtype=np.float).tolist(),
               'Hispanics': np.array(total_hispanics, dtype=np.float) / np.array(population_dist_hispanics, dtype=np.float).tolist(),
              }, index=index).plot(kind='bar', width=0.8).legend(bbox_to_anchor=(1.1, 1))
